# %%
# %pylab inline
from scipy.optimize import curve_fit
import scipy.interpolate as interpolate
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
dd = pd.read_excel("C:\\Users\\RAJAT GUPTA\\Desktop\\Messi\\datafile.xls")
prev = 0;
curr = 0;
time = 0;
for i in dd.index:
    if(dd.loc[i].X_value == '\n'):
        curr = i;
        d1 = dd[prev:curr]
        rgb = (random.random(),random.random(),random.random())
        plt.plot(d1.X_value.astype(int),-1*d1.Y_value.astype(int))
        prev = curr + 1
        
plt.show()
